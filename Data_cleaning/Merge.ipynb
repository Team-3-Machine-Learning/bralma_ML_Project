# %% [markdown]
# Merge to make 1 csv file

# %%
import pandas as pd
import glob
import os

# Path to folder containing your CSV files
path = "../data/"

# Get all CSV files in the folder
all_files = glob.glob(os.path.join(path, "*.csv"))
print("Found files:", all_files)

# Create an empty list to store dataframes
dfs = []

for file in sorted(all_files):
    df = pd.read_csv(file)
    
    # Optional: add a 'Year' column (if not already in data)
    # You can extract the year from the filename
    year = os.path.basename(file).split('_')[-1].split('.')[0]
    df['Year'] = year
    
    dfs.append(df)

# Combine all into one DataFrame
combined = pd.concat(dfs, ignore_index=True)

# Save as one combined CSV
combined.to_csv("electricity_demand_2001_2025.csv", index=False)

print("✅ Combined file created successfully!")
# Out:
# Found files: ['../data/demanddata_2022.csv', '../data/demanddata_2023.csv', '../data/demanddata_2021.csv', '../data/demanddata_2009.csv', '../data/demanddata_2008.csv', '../data/demanddata_2020.csv', '../data/demanddata_2018.csv', '../data/demanddata_2024.csv', '../data/demanddata_2025.csv', '../data/demanddata_2019.csv', '../data/demanddata_2017.csv', '../data/demanddata_2003.csv', '../data/demanddata_2002.csv', '../data/demanddata_2016.csv', '../data/demanddata_2014.csv', '../data/demanddata_2015.csv', '../data/demanddata_2001.csv', '../data/demanddata_2005.csv', '../data/demanddata_2011.csv', '../data/demanddata_2010.csv', '../data/demanddata_2004.csv', '../data/demanddata_2012.csv', '../data/demanddata_2006.csv', '../data/demanddata_2007.csv', '../data/demanddata_2013.csv']
# ✅ Combined file created successfully!
