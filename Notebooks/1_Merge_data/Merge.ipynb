# %% [markdown]
# Merge to make 1 csv file

# %%
import pandas as pd
import glob
import os

# Path to folder containing your CSV files
path = "../../Data/Raw/"

# Get all CSV files in the folder
all_files = glob.glob(os.path.join(path, "*.csv"))
print("Found files:", all_files)

# Create an empty list to store dataframes
dfs = []

for file in sorted(all_files):
    df = pd.read_csv(file)
    
    # Optional: add a 'Year' column (if not already in data)
    # You can extract the year from the filename
    year = os.path.basename(file).split('_')[-1].split('.')[0]
    df['Year'] = year
    
    dfs.append(df)

# Combine all into one DataFrame
combined = pd.concat(dfs, ignore_index=True)
combined.columns = [col.lower() for col in combined.columns]

# Save as one combined CSV
combined.to_csv("../../Data/Merged/electricity_demand_2001_2025.csv", index=False)

print("✅ Combined file created successfully!")
# Out:
# Found files: ['../../Data/Raw/demanddata_2022.csv', '../../Data/Raw/demanddata_2023.csv', '../../Data/Raw/demanddata_2021.csv', '../../Data/Raw/demanddata_2009.csv', '../../Data/Raw/demanddata_2008.csv', '../../Data/Raw/demanddata_2020.csv', '../../Data/Raw/demanddata_2018.csv', '../../Data/Raw/demanddata_2024.csv', '../../Data/Raw/demanddata_2025.csv', '../../Data/Raw/demanddata_2019.csv', '../../Data/Raw/demanddata_2017.csv', '../../Data/Raw/demanddata_2003.csv', '../../Data/Raw/demanddata_2002.csv', '../../Data/Raw/demanddata_2016.csv', '../../Data/Raw/demanddata_2014.csv', '../../Data/Raw/demanddata_2015.csv', '../../Data/Raw/demanddata_2001.csv', '../../Data/Raw/demanddata_2005.csv', '../../Data/Raw/demanddata_2011.csv', '../../Data/Raw/demanddata_2010.csv', '../../Data/Raw/demanddata_2004.csv', '../../Data/Raw/demanddata_2012.csv', '../../Data/Raw/demanddata_2006.csv', '../../Data/Raw/demanddata_2007.csv', '../../Data/Raw/demanddata_2013.csv']
# ✅ Combined file created successfully!
