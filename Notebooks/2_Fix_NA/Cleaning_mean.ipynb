# %%
# !pip3 install pandas numpy
import pandas as pd
import numpy as np
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
# Load data
df = pd.read_csv("../../Dataset1/Merged/electricity_demand_2001_2025.csv")
df
# Out:
# /var/folders/y0/9zbck24x5017gh20l_rnx3wr0000gn/T/ipykernel_77569/1153635395.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../Dataset1/Merged/electricity_demand_2001_2025.csv")
#        settlement_date  settlement_period       nd      tsd  \
# 0           2001-01-01                1.0  38631.0      NaN
# 1           2001-01-01                2.0  39808.0      NaN
# 2           2001-01-01                3.0  40039.0      NaN
# 3           2001-01-01                4.0  39339.0      NaN
# 4           2001-01-01                5.0  38295.0      NaN
# ...                ...                ...      ...      ...
# 434001      2025-10-03               44.0  25095.0  26540.0
# 434002      2025-10-03               45.0  23308.0  24743.0
# 434003      2025-10-03               46.0  22176.0  23499.0
# 434004      2025-10-03               47.0  20740.0  22457.0
# ...

# %%
# Checked welke kolommen NA-values hebben
na_columns = df.columns[df.isna().any()].tolist()
print("Kolommen met NA waarden:", na_columns)
# Out:
# Kolommen met NA waarden: ['settlement_date', 'settlement_period', 'nd', 'tsd', 'england_wales_demand', 'embedded_wind_generation', 'embedded_wind_capacity', 'embedded_solar_generation', 'embedded_solar_capacity', 'non_bm_stor', 'pump_storage_pumping', 'scottish_transfer', 'ifa_flow', 'ifa2_flow', 'britned_flow', 'moyle_flow', 'east_west_flow', 'nemo_flow', 'nsl_flow', 'eleclink_flow', 'viking_flow', 'greenlink_flow', '2005-01-01', '8', '31851', '0', '27976', 'na', 'na.1', 'na.2', 'na.3', '0.1', '504', 'na.4', '2001', 'na.5', 'na.6', '0.2', 'na.7', 'na.8', 'na.9', 'na.10', 'na.11', 'na.12']

# %%
# Bereken de mean voor elke kolom
means = df.mean(numeric_only=True)
print(means)
# Out:
# settlement_period               24.500110
# nd                           33114.266431
# tsd                          33474.505754
# england_wales_demand         30062.462929
# embedded_wind_generation      1214.371730
# embedded_wind_capacity        4144.955061
# embedded_solar_generation      967.462261
# embedded_solar_capacity       9378.041956
# non_bm_stor                      5.062030
# pump_storage_pumping           311.740801
# scottish_transfer             1743.162101
# ifa_flow                       938.989596
# ifa2_flow                       83.916384
# britned_flow                   482.953404
# moyle_flow                    -126.472139
# east_west_flow                 -57.327766
# nemo_flow                      179.188509
# nsl_flow                       493.492825
# eleclink_flow                  173.029258
# viking_flow                     97.572150
# greenlink_flow                 -35.320145
# year                          2012.882638
# ...

# %%
df_filled = df.fillna(means)
df_filled.to_csv("../../Dataset1/Cleaned/electricity_demand_2001_2025_mean.csv", index=False)
print("✅ Bestand opgeslagen als electricity_demand_2001_2025_mean.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 2
#       1 df_filled = df.fillna(means)
# ----> 2 df_filled.to_csv("../../Dataset1/Cleaned/electricity_demand_2001_2025_mean.csv", index=False)
#       3 print("✅ Bestand opgeslagen als electricity_demand_2001_2025_mean.csv")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
