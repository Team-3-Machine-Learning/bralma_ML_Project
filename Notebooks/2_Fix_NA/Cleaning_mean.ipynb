# %%
# !pip install pandas numpy
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pandas in /Users/mauroleonardo/Documents/School_2526/ML/ML_AWS_Challenge/Project/bralma_ML_Project/.venv/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Users/mauroleonardo/Documents/School_2526/ML/ML_AWS_Challenge/Project/bralma_ML_Project/.venv/lib/python3.11/site-packages (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mauroleonardo/Documents/School_2526/ML/ML_AWS_Challenge/Project/bralma_ML_Project/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mauroleonardo/Documents/School_2526/ML/ML_AWS_Challenge/Project/bralma_ML_Project/.venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mauroleonardo/Documents/School_2526/ML/ML_AWS_Challenge/Project/bralma_ML_Project/.venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/mauroleonardo/Documents/School_2526/ML/ML_AWS_Challenge/Project/bralma_ML_Project/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Load data
df = pd.read_csv("../../Dataset1/Merged/electricity_demand_2001_2025.csv")
df
# Out:
#        settlement_date  settlement_period     nd      tsd  \
# 0           2001-01-01                  1  38631      NaN
# 1           2001-01-01                  2  39808      NaN
# 2           2001-01-01                  3  40039      NaN
# 3           2001-01-01                  4  39339      NaN
# 4           2001-01-01                  5  38295      NaN
# ...                ...                ...    ...      ...
# 434009      2025-10-03                 44  25095  26540.0
# 434010      2025-10-03                 45  23308  24743.0
# 434011      2025-10-03                 46  22176  23499.0
# 434012      2025-10-03                 47  20740  22457.0
# 434013      2025-10-03                 48  19877  22013.0
#
#         england_wales_demand  embedded_wind_generation  \
# 0                      34060                       NaN
# 1                      35370                       NaN
# 2                      35680                       NaN
# 3                      35029                       NaN
# 4                      34047                       NaN
# ...                      ...                       ...
# 434009                 23271                    5343.0
# 434010                 21619                    5268.0
# 434011                 20725                    5192.0
# 434012                 19448                    5271.0
# 434013                 18729                    5350.0
#
#         embedded_wind_capacity  embedded_solar_generation  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 434009                  6606.0                        0.0
# 434010                  6606.0                        0.0
# 434011                  6606.0                        0.0
# 434012                  6606.0                        0.0
# 434013                  6606.0                        0.0
#
#         embedded_solar_capacity  non_bm_stor  ...  ifa2_flow  britned_flow  \
# 0                           NaN            0  ...        NaN           NaN
# 1                           NaN            0  ...        NaN           NaN
# 2                           NaN            0  ...        NaN           NaN
# 3                           NaN            0  ...        NaN           NaN
# 4                           NaN            0  ...        NaN           NaN
# ...                         ...          ...  ...        ...           ...
# 434009                  20993.0            0  ...      580.0         409.0
# 434010                  20993.0            0  ...     -245.0         443.0
# 434011                  20993.0            0  ...     -321.0         435.0
# 434012                  20993.0            0  ...     -220.0        -325.0
# 434013                  20993.0            0  ...     -212.0        -379.0
#
#         moyle_flow  east_west_flow  nemo_flow  nsl_flow  eleclink_flow  \
# 0              NaN             NaN        NaN       NaN            NaN
# 1              NaN             NaN        NaN       NaN            NaN
# 2              NaN             NaN        NaN       NaN            NaN
# 3              NaN             NaN        NaN       NaN            NaN
# 4              NaN             NaN        NaN       NaN            NaN
# ...            ...             ...        ...       ...            ...
# 434009       231.0             0.0     -626.0     476.0          607.0
# 434010       135.0             0.0     -254.0     105.0          266.0
# 434011        99.0             0.0     -226.0      39.0          230.0
# 434012        38.0           -11.0      179.0    -144.0         -196.0
# 434013       -36.0          -110.0      208.0    -162.0         -232.0
#
#         viking_flow  greenlink_flow  year
# 0               NaN             NaN  2001
# 1               NaN             NaN  2001
# 2               NaN             NaN  2001
# 3               NaN             NaN  2001
# 4               NaN             NaN  2001
# ...             ...             ...   ...
# 434009       1424.0           499.0  2025
# 434010       1399.0           496.0  2025
# 434011       1386.0           504.0  2025
# 434012        743.0           505.0  2025
# 434013        680.0           434.0  2025
#
# [434014 rows x 23 columns]

# %%
# Checked welke kolommen NA-values hebben
na_columns = df.columns[df.isna().any()].tolist()
print("Kolommen met NA waarden:", na_columns)
# Out:
# Kolommen met NA waarden: ['tsd', 'embedded_wind_generation', 'embedded_wind_capacity', 'embedded_solar_generation', 'embedded_solar_capacity', 'scottish_transfer', 'ifa2_flow', 'britned_flow', 'moyle_flow', 'east_west_flow', 'nemo_flow', 'nsl_flow', 'eleclink_flow', 'viking_flow', 'greenlink_flow']

# %%
# Bereken de mean voor elke kolom
means = df.mean(numeric_only=True)
print(means)
# Out:
# settlement_period               24.500115
# nd                           33356.066355
# tsd                          33266.062044
# england_wales_demand         30276.803767
# embedded_wind_generation      1214.371730
# embedded_wind_capacity        4144.955061
# embedded_solar_generation      967.462261
# embedded_solar_capacity       9378.041956
# non_bm_stor                      5.085905
# pump_storage_pumping           312.552316
# scottish_transfer             1743.162101
# ifa_flow                       949.465600
# ifa2_flow                       83.916384
# britned_flow                   482.953404
# moyle_flow                    -125.896984
# east_west_flow                 -57.327766
# nemo_flow                      179.188509
# nsl_flow                       493.492825
# eleclink_flow                  173.029258
# viking_flow                     97.572150
# greenlink_flow                 -35.320145
# year                          2012.882492
# dtype: float64

# %%
df_filled = df.fillna(means)
df_filled.to_csv("../../Dataset1/Cleaned/electricity_demand_2001_2025_mean.csv", index=False)
print("✅ Bestand opgeslagen als electricity_demand_2001_2025_mean.csv")
# Out:
# ✅ Bestand opgeslagen als electricity_demand_2001_2025_mean.csv
