# %% [markdown]
# # Fixing NA values in the dataset
# We need to fix all null values in our dataset.

# %%
import pandas as pd

path = "../Dataset1_UK_Housing/1_price_paid_records_restructured.csv"
path_out_mean = "../Dataset1_UK_Housing/2_price_paid_records_mean.csv"
path_out_zero = "../Dataset1_UK_Housing/2_price_paid_records_zero.csv"
path_out_na = "../Dataset1_UK_Housing/2_price_paid_records_na.csv"

# %% [markdown]
# ### Using the mean
# Our first tactic is to replace all NA values using the mean value of that column.

# %%
df = pd.read_csv(path)
means = df.mean(numeric_only=True)
df_filled = df.fillna(means)
df_filled.to_csv(path_out_mean, index=False)

diff = df.ne(df_filled)
rows_changed = diff.any(axis=1).sum()
column_changes = diff.sum().sort_values(ascending=False)

top_3_columns = column_changes.head(3)

print("Rows changed:", rows_changed)
if rows_changed != 0:
    print("Top 3 changed columns:")
    print(top_3_columns)
# Out:
# Rows changed: 0

# %% [markdown]
# ### Using zero
# Our second tactic is to replace all null values with zero.

# %%
df = pd.read_csv(path)
df_filled = df.fillna(0)
df_filled.to_csv(path_out_zero, index=False)

diff = df.ne(df_filled)
rows_changed = diff.any(axis=1).sum()
column_changes = diff.sum().sort_values(ascending=False)

top_3_columns = column_changes.head(3)

print("Rows changed:", rows_changed)
if rows_changed != 0:
    print("Top 3 changed columns:")
    print(top_3_columns)
# Out:
# Rows changed: 0

# %% [markdown]
# ### Using NA
# Our third tactic is to replace all null values with NA.

# %%
df = pd.read_csv(path)
df = df.fillna('NA')
df.to_csv(path_out_na, index=False)

diff = df.ne(df_filled)
rows_changed = diff.any(axis=1).sum()
column_changes = diff.sum().sort_values(ascending=False)

top_3_columns = column_changes.head(3)

print("Rows changed:", rows_changed)
if rows_changed != 0:
    print("Top 3 changed columns:")
    print(top_3_columns)
# Out:
# Rows changed: 0

# %% [markdown]
# Fixing NA values is not needed for this dataset because there are no NA values to begin with.
